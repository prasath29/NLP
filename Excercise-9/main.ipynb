# %%
import pandas as pd
import nltk
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from nltk.tokenize import word_tokenize

# %%
from nltk.corpus import stopwords

# %%
with open("nlp.txt", "r", encoding="utf-8") as f:
    df = pd.DataFrame(data=f.readlines(), columns=["text"])

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060] A
# [nltk_data]     connection attempt failed because the connected party
# [nltk_data]     did not properly respond after a period of time, or
# [nltk_data]     established connection failed because connected host
# [nltk_data]     has failed to respond>
# False

# %%
stop_words = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')

# %%
def preprocess_text(text):
    text = text.lower().replace('[^a-zA-Z0-9\s]', '')
    words = word_tokenize(text)
    words = [w for w in words if w not in stop_words]
    words = [stemmer.stem(w) for w in words]
    return ' '.join(words)

# %%
df['text'] = df['text'].apply(preprocess_text)

# %%
df.head()
# Out:
#                                              text
# 0  ed : come come @ 60183560200 @ 60197773622 🤣🤣🤣
# 1                                rohit : good boy
# 2                   ed : share knowledg pass year
# 3                          ed : easi communic 🤣🤣🤣
# 4                                        ed : bad

# %% [markdown]
# #OR

# %%
df['polarity'] = df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['sentiment'] = df['polarity'].apply(lambda x: 'positive' if x > 0 else 'negative' if x < 0 else 'neutral')

df.head()
# Out:
#                                              text  polarity sentiment
# 0  ed : come come @ 60183560200 @ 60197773622 🤣🤣🤣       0.0   neutral
# 1                                rohit : good boy       0.7  positive
# 2                   ed : share knowledg pass year       0.0   neutral
# 3                          ed : easi communic 🤣🤣🤣       0.0   neutral
# 4                                        ed : bad      -0.7  negative

# %% [markdown]
# # OR

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from textblob import TextBlob

df = pd.read_csv('whatsapp-chat-data.txt', header=None, names=['text'], error_bad_lines=False)


df.dropna(inplace=True)


df['text'] = df['text'].astype(str)


stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()


def preprocess_text(text):
    text = text.lower().replace('[^a-zA-Z0-9\s]', '')
    words = word_tokenize(text)
    words = [w for w in words if w not in stop_words]
    words = [stemmer.stem(w) for w in words]
    return words

df['text_processed'] = df['text'].apply(preprocess_text)
df['polarity'] = df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)
df['sentiment'] = df['polarity'].apply(lambda x: 'positive' if x > 0 else 'negative' if x < 0 else 'neutral')


print(df.head())
# Out:
# C:\Users\Hariprasath\AppData\Local\Temp\ipykernel_16524\3376469305.py:8: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv('whatsapp-chat-data.txt', header=None, names=['text'], error_bad_lines=False)
# Skipping line 587: expected 4 fields, saw 7
# Skipping line 648: expected 4 fields, saw 5
# Skipping line 1029: expected 4 fields, saw 6
# Skipping line 1033: expected 4 fields, saw 5
# Skipping line 1299: expected 4 fields, saw 5
# Skipping line 1340: expected 4 fields, saw 5
# Skipping line 1406: expected 4 fields, saw 7
# Skipping line 1409: expected 4 fields, saw 5
# Skipping line 1659: expected 4 fields, saw 5
# Skipping line 2146: expected 4 fields, saw 5
# Skipping line 2577: expected 4 fields, saw 7
# Skipping line 2621: expected 4 fields, saw 5
# Skipping line 2673: expected 4 fields, saw 5
# Skipping line 2861: expected 4 fields, saw 6
# ...
